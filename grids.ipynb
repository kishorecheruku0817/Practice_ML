# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('iris')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
gr = sns.PairGrid(data=data)
gr.map_diag(sns.histplot)
gr.map_lower(sns.kdeplot)
gr.map_upper(sns.scatterplot)

# %%
tips = sns.load_dataset('tips')
g = sns.FacetGrid(tips, col='time', row='smoker')
g.map(sns.kdeplot, 'total_bill')

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', markers=['o', '^'], scatter_kws={'s': 50})

# %%
sns.set_style('whitegrid')
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', hue='sex', aspect=.5, markers=['o','^'], palette='seismic')

# %%
tips.pivot_table(index='smoker', columns='sex', values= 'total_bill', aggfunc='count').head(10)
# Out:
# /var/folders/39/mvl07frs18l0n9lf92sybq1r0000gn/T/ipykernel_94438/1319956199.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index='smoker', columns='sex', values= 'total_bill', aggfunc='count').head(10)
# sex     Male  Female
# smoker
# Yes       60      33
# No        97      54

# %%
sum(tips['sex'] == 'Female')
# Out:
# 87

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Exercises
#
# ** Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Keep careful attention to the x and y labels for hints.**
#
# ** *Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!* **

# %%
sns.jointplot(data=titanic, x='fare', y='age')
plt.show()

# %%
sns.boxplot(data=titanic, x='class', y='age', palette="coolwarm")
plt.show()
# Out:
# /var/folders/39/mvl07frs18l0n9lf92sybq1r0000gn/T/ipykernel_12926/2301990985.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=titanic, x='class', y='age', palette="coolwarm")

# %%
sns.swarmplot(data=titanic, x='class', y='age', palette="coolwarm")
plt.show()
# Out:
# /var/folders/39/mvl07frs18l0n9lf92sybq1r0000gn/T/ipykernel_12926/3840247798.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=titanic, x='class', y='age', palette="coolwarm")
# /Applications/anaconda3/lib/python3.13/site-packages/seaborn/categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(data=titanic, x='sex', palette='seismic')
plt.show()
# Out:
# /var/folders/39/mvl07frs18l0n9lf92sybq1r0000gn/T/ipykernel_12926/4198586160.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic, x='sex', palette='seismic')

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.heatmap(titanic.corr(numeric_only=True), cmap='coolwarm')
plt.show()

# %%
g = sns.FacetGrid(data=titanic, col='sex')
g.map(plt.hist, 'age')
plt.show()
