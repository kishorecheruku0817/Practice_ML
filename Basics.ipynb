# %%
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
tuple = (1,2,3)

# %%
tuple[0]
# Out:
# 1

# %%
tuple[0] = "kishore"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tuple[0] = "kishore"
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list[0]
# Out:
# 1

# %%
my_list[0] = "New"

# %%
my_list
# Out:
# ['New', 2, 3]

# %%
{1,2,2,2,2,3,4}
# Out:
# {1, 2, 3, 4}

# %%
nums = [1,1,1,2,3,3,4,5,5,5,6]

# %%
set(nums)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
nums
# Out:
# [1, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6]

# %%
nums.append(5)

# %%
nums
# Out:
# [1, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5]

# %%
nums.append(7)

# %%
nums
# Out:
# [1, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7]

# %%
nums.insert(0,100)

# %%
nums
# Out:
# [100, 1, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7]

# %%
nums.remove(1)

# %%
nums
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7]

# %%
nums.reverse
# Out:
# <function list.reverse()>

# %%
nums
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7]

# %%
print(nums.reverse)
# Out:
# <built-in method reverse of list object at 0x13ac26300>

# %%
reverse = nums.reverse

# %%
reverse
# Out:
# <function list.reverse()>

# %%
nums.pop([0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 nums.pop([0])
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
nums.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
nums
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7]

# %%
nums.pop
# Out:
# <function list.pop(index=-1, /)>

# %% [markdown]
# nums

# %%
nums.count(1)
# Out:
# 2

# %%
nums.extend([0,1,2,3])

# %%
nums
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7, 0, 1, 2, 3]

# %%
t = (5)

# %%
t
# Out:
# 5

# %%
t[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 t[0]
#
# TypeError: 'int' object is not subscriptable

# %%
t = (5,)

# %%
t[0]
# Out:
# 5

# %%
t = (1,2)

# %%
t[0]
# Out:
# 1

# %%
nums[-1]
# Out:
# 3

# %%
nums
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 5, 5, 6, 5, 7, 0, 1, 2, 3]

# %%
dict = {"name": "kishore", "age": 38, "is_employed": True}

# %%
dict
# Out:
# {'name': 'kishore', 'age': 38, 'is_employed': True}

# %%
dict['name']
# Out:
# 'kishore'

# %%
dict("unknow")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 dict("unknow")
#
# TypeError: 'dict' object is not callable

# %%
dict('name'
    )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 dict('name'
#       2     )
#
# TypeError: 'dict' object is not callable

# %%
dict.get("key")

# %%
dict.get("key", "Key not found")
# Out:
# 'Key not found'

# %%
dict.keys().first
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 dict.keys().first
#
# AttributeError: 'dict_keys' object has no attribute 'first'

# %%
dict.items
# Out:
# <function dict.items()>

# %%
for k, v in dict.items():
  print(f"{k} {v}")
# Out:
# name kishore
# age 38
# is_employed True

# %%
square = {x: x*x for x in range(5)}

# %%
square
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
a = {"x": 1}
b = {"y": 2}
merged = a | b

# %%
merged
# Out:
# {'x': 1, 'y': 2}

# %%
l = lambda x: x** 2

# %%
l(3)
# Out:
# 9

# %%
nums = [1,2,3,4,5]

# %%
print(list(map(lambda x: x**2, nums)))
# Out:
# [1, 4, 9, 16, 25]

# %%
squared = list(map(lambda x: x**2, nums))

# %%
def times2(val):
    return val*2

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
[times2(x) for x in nums]
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(times2, nums))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(filter(lambda x: x % 2 == 0, nums))
# Out:
# [2, 4]

# %%
times2 = lambda x: x * 2

# %%
list(map(times2, nums))
# Out:
# [2, 4, 6, 8, 10]

# %%
x = [(1,2), (3,4), (5,6)]

# %%
for item in x:
    for v in item:
        print(v)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
